# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import datasets

# %%
iris = datasets.load_iris()
X = iris.data[:, :2]  # we only take the first two features.
y = iris.target

# %%
X_size = X.shape[0]
print(X_size)
#print(X)
# Out:
# 150

# %%
K = [3,4,5]
point
#cluster
#print(point[0] = X[0, : ])
for i in range(3):
    point[i] = X[i, : ]
print(point[0], point[1], point[2])
#point1 = X[0, : ]
#point2 = X[1, : ]
#point3 = X[2, : ] 
#print(point1, point2, point3)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-2a7b6aa7825b> in <module>
#       4 #print(point[0] = X[0, : ])
#       5 for i in range(3):
# ----> 6     point[i] = X[i, : ]
#       7 print(point[0], point[1], point[2])
#       8 #point1 = X[0, : ]
#
# IndexError: list assignment index out of range

# %%
list1 = np.zeros((X_size, 1))
list2 = np.zeros((X_size, 1))
list3 = np.zeros((X_size, 1))
for i in range (len(k))
sumfx = 0
sumfy = 0
    for k in range(200) :
        for i in range(X_size) :
            list1[i] = np.sqrt((np.sum((point1 - X[i])**2)))
            list2[i] = np.sqrt((np.sum((point2 - X[i])**2)))
            list3[i] = np.sqrt((np.sum((point3 - X[i])**2)))
        cluster1 = []
        cluster2 = []
        cluster3 = []
        for i in range(X_size) :
            if ((list1[i] <= list2[i]) and (list1[i] <= list3[i])) :
                cluster1.append((X[i]))
            elif ((list2[i] <= list1[i]) and (list2[i] <= list3[i])) :
                cluster2.append((X[i]))
            else :
                cluster3.append((X[i]))
        print(len(cluster1), len(cluster2), len(cluster3))
        summx = 0
        summy = 0
        for i in range(len(cluster1)) :
            summx += cluster1[i][0]
            summy += cluster1[i][1]     
            sumfx += summx
            sumfy += summy
#        point1[0] = summx/len(cluster1)
#        point1[1] = summy/len(cluster1)

        summx = 0
        summy = 0
        for i in range(len(cluster2)) :
            summx += cluster2[i][0]
            summy += cluster2[i][1]        
            sumfx += summx
            sumfy += summy
#        point2[0] = summx/len(cluster2)
#        point2[1] = summy/len(cluster2)

        summx = 0
        summy = 0
        for i in range(len(cluster3)) :
            summx += cluster3[i][0]
            summy += cluster3[i][1]        
            sumfx += summx
            sumfy += summy
        sumfx = sumfx/3
        sumfy = sumfy/3
#        point3[0] = summx/len(cluster3)
#        point3[1] = summy/len(cluster3)
        point[k] = sumfx/len(cluster) 
        print(point[0], point[1], point[2])
# Out:
# 48 54 48
# [6.81276596 3.07446809] [5.77358491 2.69245283] [5.01276596 3.44042553]
# 48 54 48
# [6.81276596 3.07446809] [5.77358491 2.69245283] [5.01276596 3.44042553]
# 48 54 48
# [6.81276596 3.07446809] [5.77358491 2.69245283] [5.01276596 3.44042553]
# 48 54 48
# [6.81276596 3.07446809] [5.77358491 2.69245283] [5.01276596 3.44042553]
# 48 54 48
# [6.81276596 3.07446809] [5.77358491 2.69245283] [5.01276596 3.44042553]
# 48 54 48
# [6.81276596 3.07446809] [5.77358491 2.69245283] [5.01276596 3.44042553]
# 48 54 48
# [6.81276596 3.07446809] [5.77358491 2.69245283] [5.01276596 3.44042553]
# 48 54 48
# [6.81276596 3.07446809] [5.77358491 2.69245283] [5.01276596 3.44042553]
# 48 54 48
# [6.81276596 3.07446809] [5.77358491 2.69245283] [5.01276596 3.44042553]
# 48 54 48
# [6.81276596 3.07446809] [5.77358491 2.69245283] [5.01276596 3.44042553]
# 48 54 48
# [6.81276596 3.07446809] [5.77358491 2.69245283] [5.01276596 3.44042553]
# 48 54 48
# ...

# %%
#print(list1[:10, :], "\n\n", list2[:10, :], "\n\n", list3[:10, :])

print(len(cluster1), len(cluster2), len(cluster3))
# Out:
# 48 54 48

# %%
print(len(cluster1))
# Out:
# 48

# %%
print(len(cluster2))
# Out:
# 54

# %%
print(len(cluster3))
# Out:
# 48
